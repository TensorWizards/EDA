# %% [markdown]
# <h1><p><center style="background: linear-gradient(to right,white,green);color: transparent;font-family: Gabriola;color: navy;font-size: 210%;text-align: center;border-radius: 10px 70px">
#     LOKSABHA ELECTION EDA
# </center></p></h1>

# %% [markdown]
# <a class="anchor" id="setup"></a>
# <br>
# <br>
# <br>
# <font style="font-family:Gabriola; font-size:300%;">1️⃣ Step 1 | About Dataset </font><br>
#  <br>
# <br>

# %% [markdown]
# <div style = 'border : 3px solid non; background-color:#F0FFFF ; ;padding:10px'>
#
# <a class="anchor" id="about_dataset"></a>
#
# <p style="font-family:Georgia;padding:20px;line-height:25px;";><font style="font-family:Georgia; font-size:210%;"> 👁‍🗨Information </font><br>
#
#
#
# **Welcome, data enthusiasts!**
#
# The `election_results_2024.csv` dataset contains the following columns:
#
# 1. **Constituency**: Name of the electoral constituency.
# 2. **Const. No.**: Unique identifier number for the constituency.
# 3. **Leading Candidate**: Name of the winning candidate.
# 4. **Leading Party**: Party of the winning candidate.
# 5. **Trailing Candidate**: Name of the candidate who lost.
# 6. **Trailing Party**: Party of the losing candidate.
# 7. **Margin**: Vote difference between the leading and trailing candidates.
# 8. **Status**: Status of the result, typically "Result Declared".
#
# ### Possible Explorations
#
# 1. **Distribution of Margins**: Analyze the winning margins.
# 2. **Party Analysis**: Count and compare seats won by each party.
# 3. **Regional Patterns**: Explore geographic trends if more location data is available.
# 4. **Close Contests and Landslide Victories**: Identify closely contested and landslide win constituencies.
# <br>

# %% [markdown]
# <a class="anchor" id="setup"></a>
# <br>
# <br>
# <br>
# <font style="font-family:Gabriola; font-size:300%;">2️⃣ Step 2 | Python Libraries </font><br>
#  <br>
# <br>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <a class="anchor" id="data"></a>
# <br>
# <br>
# <br>
# <font style="font-family:Gabriola; font-size:300%;">3️⃣ Step 3 | Data </font><br>
#  <br>
# <br>

# %% [markdown]
# <a id="2"></a>
# # <p style="background-color:#3B6978;font-family:newtimeroman;color:#FFF9ED;font-size:150%;text-align:center;border-radius:10px 10px;">Reading Data</p>

# %%
df = pd.read_csv('election_results_2024.csv')

# Display the first few rows of the dataframe
print("First few rows of the dataframe:")
print(df.head())

# Basic summary
print("Basic summary of the dataset:")
print(df.info())
# Out:
# First few rows of the dataframe:
#        Constituency  Const. No.    Leading Candidate  \
# 0             AJMER          13  BHAGIRATH CHOUDHARY
# 1             ALWAR           8      BHUPENDER YADAV
# 2            AMBALA           1       VARUN CHAUDHRY
# 3  ANANTNAG-RAJOURI           3     MIAN ALTAF AHMAD
# 4         ARAKKONAM           7    S JAGATHRATCHAKAN
#
#                          Leading Party    Trailing Candidate  \
# 0               Bharatiya Janata Party  RAMCHANDRA CHOUDHARY
# 1               Bharatiya Janata Party           LALIT YADAV
# 2             Indian National Congress         BANTO KATARIA
# 3  Jammu & Kashmir National Conference        MEHBOOBA MUFTI
# 4            Dravida Munnetra Kazhagam             L VIJAYAN
#
#                              Trailing Party  Margin           Status
# 0                  Indian National Congress  329991  Result Declared
# 1                  Indian National Congress   48282  Result Declared
# ...

# %%
df
# Out:
#          Constituency  Const. No.         Leading Candidate  \
# 0               AJMER          13       BHAGIRATH CHOUDHARY
# 1               ALWAR           8           BHUPENDER YADAV
# 2              AMBALA           1            VARUN CHAUDHRY
# 3    ANANTNAG-RAJOURI           3          MIAN ALTAF AHMAD
# 4           ARAKKONAM           7         S JAGATHRATCHAKAN
# ..                ...         ...                       ...
# 538            Wardha           8       AMAR SHARADRAO KALE
# 539           Wayanad           4              RAHUL GANDHI
# 540        West Delhi           6        KAMALJEET SEHRAWAT
# 541  Yavatmal- Washim          14  SANJAY UTTAMRAO DESHMUKH
# 542         Zahirabad           5      SURESH KUMAR SHETKAR
#
#                                         Leading Party  \
# 0                              Bharatiya Janata Party
# 1                              Bharatiya Janata Party
# 2                            Indian National Congress
# ...

# %% [markdown]
# <a id="6"></a>
# # <p style="background-color:#3B6978;font-family:newtimeroman;color:#FFF9ED;font-size:150%;text-align:center;border-radius:10px 10px;">Checking for NaN values</p>

# %%
df.isnull().sum()
# Out:
# Constituency          0
# Const. No.            0
# Leading Candidate     0
# Leading Party         0
# Trailing Candidate    1
# Trailing Party        1
# Margin                0
# Status                0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Constituency          0
# Const. No.            0
# Leading Candidate     0
# Leading Party         0
# Trailing Candidate    0
# Trailing Party        0
# Margin                0
# Status                0
# dtype: int64

# %%
plt.figure(figsize=(22,10))
plt.xticks(size=20,color='grey')
plt.tick_params(size=12,color='grey')
plt.title('Finding Null Values Using Heatmap\n',color='grey',size=30)
sns.heatmap(df.isnull(),
            yticklabels=False,
            cbar=False,
            cmap='PuBu_r',
            )
plt.show()

# %% [markdown]
# <a id="5"></a>
# # <p style="background-color:#3B6978;font-family:newtimeroman;color:#FFF9ED;font-size:150%;text-align:center;border-radius:10px 10px;">Statistical information of data</p>

# %%
df.describe(include='object')
# Out:
#        Constituency Leading Candidate           Leading Party  \
# count           542               542                     542
# unique          540               541                      42
# top      Aurangabad      RAHUL GANDHI  Bharatiya Janata Party
# freq              2                 2                     239
#
#           Trailing Candidate            Trailing Party  Margin  \
# count                    542                       542     542
# unique                   542                        42     542
# top     RAMCHANDRA CHOUDHARY  Indian National Congress  329991
# freq                       1                       167       1
#
#                  Status
# count               542
# unique                1
# top     Result Declared
# freq                542

# %% [markdown]
# <p style="font-size:150%; color:#226666">💡 Election Results Summary </p>
#
# - <p style="color:#226666">Total Constituencies Analyzed: The dataset contains information for 542 constituencies.</p>
# - <p style="color:#226666">Most Frequent Constituency Name: "Aurangabad" appears twice in the dataset.</p>
# - <p style="color:#226666">Most Frequent Leading Candidate: "RAHUL GANDHI" is listed as the leading candidate in two constituencies.</p>
# - <p style="color:#226666">Most Frequent Leading Party: "Bharatiya Janata Party" leads in 239 constituencies, making it the most frequent leading party.</p>
# - <p style="color:#226666">Most Frequent Trailing Candidate: Each trailing candidate is unique with "RAMCHANDRA CHOUDHARY" appearing once.</p>
# - <p style="color:#226666">Most Frequent Trailing Party: "Indian National Congress" trails in 167 constituencies.</p>
# - <p style="color:#226666">Largest Winning Margin: The highest margin observed is 329,991 votes.</p>
# - <p style="color:#226666">Result Status: All 542 results are declared.</p>

# %%
leading_party_counts = df['Leading Party'].value_counts()
trailing_party_counts = df['Trailing Party'].value_counts()
print("\nCount of leading parties:")
print(leading_party_counts)
print("\nCount of trailing parties:")
print(trailing_party_counts)
# Out:
# Count of leading parties:
# Leading Party
# Bharatiya Janata Party                                      239
# Indian National Congress                                     99
# Samajwadi Party                                              37
# All India Trinamool Congress                                 29
# Dravida Munnetra Kazhagam                                    22
# Telugu Desam                                                 16
# Janata Dal (United)                                          12
# Shiv Sena (Uddhav Balasaheb Thackrey)                         9
# Nationalist Congress Party – Sharadchandra Pawar              8
# Shiv Sena                                                     7
# Independent                                                   7
# Lok Janshakti Party(Ram Vilas)                                5
# Communist Party of India (Marxist)                            4
# Yuvajana Sramika Rythu Congress Party                         4
# ...

# %% [markdown]
# <a id="4"></a>
# # <p style="background-color:#3B6978;font-family:newtimeroman;color:#FFF9ED;font-size:150%;text-align:center;border-radius:10px 10px;">Meta information of dataframe</p>

# %%
print(f'Shape of dataframe is: {df.shape}')
# Out:
# Shape of dataframe is: (542, 8)

# %% [markdown]
# <a class="anchor" id="EDA"></a>
# <br>
# <br>
# <br>
# <font style="font-family:Gabriola; font-size:300%;">4️⃣ Step 4 | EDA </font><br>
#  <br>
# <br>

# %% [markdown]
# <a id="8"></a>
# # <p style="background-color:#3B6978;font-family:newtimeroman;color:#FFF9ED;font-size:150%;text-align:center;border-radius:10px 10px;">Visualization</p>

# %%
# Plotting the count of leading parties
plt.figure(figsize=(10, 6))
sns.countplot(x='Leading Party', data=df, order=leading_party_counts.index)
plt.title('Count of Leading Parties')
plt.xlabel('Leading Party')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Margin'], bins=10, kde=True)
plt.title('Distribution of Winning Margins')
plt.xlabel('Winning Margin')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\edita\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Histogram of winning margins by leading and trailing parties
plt.figure(figsize=(12, 8))
sns.histplot(df, x='Margin', hue='Status', multiple='stack', kde=True, bins=10)
plt.title('Histogram of Winning Margins by Status')
plt.xlabel('Winning Margin')
plt.ylabel('Frequency')
plt.legend(title='Status')
plt.show()
# Out:
# C:\Users\edita\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\edita\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming `df` is your DataFrame with columns 'Constituency', 'Margin', and 'Leading Party'

# Create scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x=range(len(df)), y='Margin', hue='Leading Party', cmap='viridis')
plt.title('Scatter Plot of Margins for all Constituencies')
plt.xlabel('Index')
plt.ylabel('Margin')
plt.legend(title='Leading Party', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
# Out:
# C:\Users\edita\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\seaborn\relational.py:573: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   points = ax.scatter(x=x, y=y, **kws)

# %%
import pandas as pd

# Assuming `df` is your DataFrame with columns 'Leading Party' and 'Trailing Party'

# Perform one-hot encoding
df_encoded = pd.get_dummies(df, columns=['Leading Party', 'Trailing Party'])

# Display the encoded DataFrame
print(df_encoded.head())
# Out:
#        Constituency  Const. No.    Leading Candidate    Trailing Candidate  \
# 0             AJMER          13  BHAGIRATH CHOUDHARY  RAMCHANDRA CHOUDHARY
# 1             ALWAR           8      BHUPENDER YADAV           LALIT YADAV
# 2            AMBALA           1       VARUN CHAUDHRY         BANTO KATARIA
# 3  ANANTNAG-RAJOURI           3     MIAN ALTAF AHMAD        MEHBOOBA MUFTI
# 4         ARAKKONAM           7    S JAGATHRATCHAKAN             L VIJAYAN
#
#    Margin           Status  Leading Party_AJSU Party  \
# 0  329991  Result Declared                     False
# 1   48282  Result Declared                     False
# 2   49036  Result Declared                     False
# 3  281794  Result Declared                     False
# 4  306559  Result Declared                     False
#
#    Leading Party_Aam Aadmi Party  \
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# Assuming `df` is your DataFrame with columns to be normalized

# Initialize MinMaxScaler
scaler = MinMaxScaler()

# Select columns to normalize
columns_to_normalize = ['Margin']  # Add other numeric columns as needed

# Apply normalization to selected columns
df[columns_to_normalize] = scaler.fit_transform(df[columns_to_normalize])

# Display the normalized DataFrame
print(df.head())
# Out:
#        Constituency  Const. No.    Leading Candidate  \
# 0             AJMER          13  BHAGIRATH CHOUDHARY
# 1             ALWAR           8      BHUPENDER YADAV
# 2            AMBALA           1       VARUN CHAUDHRY
# 3  ANANTNAG-RAJOURI           3     MIAN ALTAF AHMAD
# 4         ARAKKONAM           7    S JAGATHRATCHAKAN
#
#                          Leading Party    Trailing Candidate  \
# 0               Bharatiya Janata Party  RAMCHANDRA CHOUDHARY
# 1               Bharatiya Janata Party           LALIT YADAV
# 2             Indian National Congress         BANTO KATARIA
# 3  Jammu & Kashmir National Conference        MEHBOOBA MUFTI
# 4            Dravida Munnetra Kazhagam             L VIJAYAN
#
#                              Trailing Party    Margin           Status
# 0                  Indian National Congress  0.280792  Result Declared
# 1                  Indian National Congress  0.041049  Result Declared
# ...
